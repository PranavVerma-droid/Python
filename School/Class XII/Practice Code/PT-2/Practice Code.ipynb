# %% [markdown]
# # Practice Code

# %%
pip install mysql-connector-python --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

conn = mysql.connector.connect(host="localhost", user="root", passwd="123", database="test")
cur = conn.cursor()

cur.execute("CREATE TABLE IF NOT EXISTS students (Rollno INTEGER(2) NOT NULL PRIMARY KEY);")

cur.execute("SHOW TABLES;")
for i in cur:
    print(i)

cur.execute("DESCRIBE students;")
for i in cur:
    print(i)

conn.commit()
print(cur.rowcount)
conn.close()
# Out:
# ('students',)
# ('Rollno', 'int', 'NO', 'PRI', None, '')
# 1
